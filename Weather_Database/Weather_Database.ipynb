# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Put coordinates into a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []
#Identify nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
#Print the city count to confirm number
print(len(cities))
# Out:
# 740

# %%
#empty list to hold weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
#Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bf2e193e15770b55ecc82ec5fbeb7291

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Current Description": weather_desc,
                      "Country": city_country,
                      "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | catamarca
# Processing Record 2 of Set 1 | nouadhibou
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | vardo
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | beloha
# Processing Record 9 of Set 1 | olafsvik
# Processing Record 10 of Set 1 | dakar
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | kalmunai
# Processing Record 17 of Set 1 | bealanana
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | oxapampa
# Processing Record 20 of Set 1 | camana
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | ngerengere
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | marechal candido rondon
# Processing Record 32 of Set 1 | beya
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | lorengau
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | muroto
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | revda
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | sorland
# Processing Record 41 of Set 1 | partur
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | jalu
# Processing Record 44 of Set 1 | novyy urgal
# Processing Record 45 of Set 1 | northam
# Processing Record 46 of Set 1 | kieta
# Processing Record 47 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 2 | sabaudia
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | magadan
# Processing Record 4 of Set 2 | samur
# Processing Record 5 of Set 2 | biltine
# Processing Record 6 of Set 2 | nizhniy tsasuchey
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | camocim
# Processing Record 12 of Set 2 | svetlyy
# Processing Record 13 of Set 2 | coahuayana
# Processing Record 14 of Set 2 | meulaboh
# Processing Record 15 of Set 2 | tuatapere
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | geraldton
# Processing Record 19 of Set 2 | mixtequilla
# City not found. Skipping...
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | keti bandar
# Processing Record 22 of Set 2 | maniitsoq
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | sioux lookout
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | alice springs
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | namatanai
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | bereda
# Processing Record 32 of Set 2 | malinovoye ozero
# Processing Record 33 of Set 2 | basco
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | trofors
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | shenjiamen
# Processing Record 40 of Set 2 | husavik
# Processing Record 41 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | bayan
# Processing Record 44 of Set 2 | khurai
# Processing Record 45 of Set 2 | floro
# Processing Record 46 of Set 2 | novyy urengoy
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | vanavara
# Processing Record 1 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | belaya gora
# Processing Record 4 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | rebrikha
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | riyadh
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | kijang
# Processing Record 12 of Set 3 | black river
# Processing Record 13 of Set 3 | norfolk
# Processing Record 14 of Set 3 | zhangjiakou
# Processing Record 15 of Set 3 | totness
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | fare
# Processing Record 18 of Set 3 | canberra
# Processing Record 19 of Set 3 | hualmay
# Processing Record 20 of Set 3 | agadir
# Processing Record 21 of Set 3 | ternate
# Processing Record 22 of Set 3 | labuhan
# Processing Record 23 of Set 3 | torbay
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | hamilton
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | plettenberg bay
# Processing Record 28 of Set 3 | la ronge
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | inhambane
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | tymovskoye
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 3 | hofn
# Processing Record 38 of Set 3 | darnah
# Processing Record 39 of Set 3 | karratha
# Processing Record 40 of Set 3 | samarai
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | san rafael del sur
# Processing Record 43 of Set 3 | fort nelson
# Processing Record 44 of Set 3 | shiyan
# Processing Record 45 of Set 3 | jamestown
# Processing Record 46 of Set 3 | port-gentil
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | soyo
# Processing Record 49 of Set 3 | jutai
# Processing Record 50 of Set 3 | emerald
# Processing Record 1 of Set 4 | san cristobal
# Processing Record 2 of Set 4 | zychlin
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | yumen
# Processing Record 5 of Set 4 | kabinda
# Processing Record 6 of Set 4 | buala
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | kaitangata
# Processing Record 11 of Set 4 | kichera
# Processing Record 12 of Set 4 | terney
# Processing Record 13 of Set 4 | necochea
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 4 | rabo de peixe
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | naze
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | cabinda
# Processing Record 24 of Set 4 | rosarito
# Processing Record 25 of Set 4 | morden
# Processing Record 26 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 4 | cedar falls
# Processing Record 28 of Set 4 | walvis bay
# Processing Record 29 of Set 4 | mandalay
# Processing Record 30 of Set 4 | arrifes
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | trat
# Processing Record 33 of Set 4 | ust-omchug
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | rawson
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | novosheshminsk
# Processing Record 40 of Set 4 | eydhafushi
# Processing Record 41 of Set 4 | angoche
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | tromso
# Processing Record 44 of Set 4 | sarlat-la-caneda
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | florence
# Processing Record 47 of Set 4 | ust-nera
# Processing Record 48 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 4 | varadero
# Processing Record 50 of Set 4 | maltahohe
# Processing Record 1 of Set 5 | canico
# Processing Record 2 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 3 of Set 5 | sao felix do xingu
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | ajdabiya
# Processing Record 6 of Set 5 | college
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | artigas
# Processing Record 9 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 5 | faya
# Processing Record 11 of Set 5 | lazaro cardenas
# Processing Record 12 of Set 5 | comodoro rivadavia
# Processing Record 13 of Set 5 | visby
# Processing Record 14 of Set 5 | katiola
# Processing Record 15 of Set 5 | pemangkat
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | palembang
# Processing Record 18 of Set 5 | rogatica
# Processing Record 19 of Set 5 | sovetskaya gavan
# Processing Record 20 of Set 5 | tomatlan
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | airai
# Processing Record 24 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 5 | muisne
# Processing Record 26 of Set 5 | kigoma
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | kiunga
# Processing Record 29 of Set 5 | deputatskiy
# Processing Record 30 of Set 5 | lakes entrance
# Processing Record 31 of Set 5 | fenoarivo
# Processing Record 32 of Set 5 | south lake tahoe
# Processing Record 33 of Set 5 | madawaska
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | liwonde
# Processing Record 37 of Set 5 | sobolevo
# Processing Record 38 of Set 5 | mogadishu
# Processing Record 39 of Set 5 | nemuro
# Processing Record 40 of Set 5 | karaton
# Processing Record 41 of Set 5 | capitao poco
# Processing Record 42 of Set 5 | roald
# Processing Record 43 of Set 5 | hauterive
# Processing Record 44 of Set 5 | chhabra
# Processing Record 45 of Set 5 | dikson
# Processing Record 46 of Set 5 | soe
# Processing Record 47 of Set 5 | candido mendes
# Processing Record 48 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | dvinskoy
# Processing Record 50 of Set 5 | marsh harbour
# Processing Record 1 of Set 6 | mae sot
# Processing Record 2 of Set 6 | itarema
# Processing Record 3 of Set 6 | jumla
# Processing Record 4 of Set 6 | san andres
# Processing Record 5 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 6 | ilo
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | tiarei
# Processing Record 9 of Set 6 | barentu
# Processing Record 10 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 6 | ust-uda
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | anloga
# Processing Record 14 of Set 6 | norman wells
# Processing Record 15 of Set 6 | chokurdakh
# Processing Record 16 of Set 6 | ankazoabo
# Processing Record 17 of Set 6 | la suiza
# Processing Record 18 of Set 6 | matadi
# Processing Record 19 of Set 6 | luis correia
# Processing Record 20 of Set 6 | buluang
# Processing Record 21 of Set 6 | aswan
# Processing Record 22 of Set 6 | balikpapan
# Processing Record 23 of Set 6 | kamenka
# Processing Record 24 of Set 6 | dolores
# Processing Record 25 of Set 6 | toyooka
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | ibra
# Processing Record 29 of Set 6 | egvekinot
# Processing Record 30 of Set 6 | mayo
# Processing Record 31 of Set 6 | storforshei
# Processing Record 32 of Set 6 | saint-philippe
# Processing Record 33 of Set 6 | katherine
# Processing Record 34 of Set 6 | manokwari
# Processing Record 35 of Set 6 | salinopolis
# Processing Record 36 of Set 6 | pichayevo
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | puerto el triunfo
# Processing Record 39 of Set 6 | chongwe
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | half moon bay
# Processing Record 44 of Set 6 | voyvozh
# Processing Record 45 of Set 6 | souillac
# Processing Record 46 of Set 6 | guaymas
# Processing Record 47 of Set 6 | hornepayne
# Processing Record 48 of Set 6 | nushki
# Processing Record 49 of Set 6 | seydi
# Processing Record 50 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 7 | urucui
# Processing Record 2 of Set 7 | wakkanai
# Processing Record 3 of Set 7 | lakselv
# Processing Record 4 of Set 7 | sechura
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | waddan
# Processing Record 7 of Set 7 | poronaysk
# Processing Record 8 of Set 7 | qaanaaq
# Processing Record 9 of Set 7 | lodja
# Processing Record 10 of Set 7 | mangrol
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | wieliczka
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | saint combs
# City not found. Skipping...
# Processing Record 15 of Set 7 | lata
# Processing Record 16 of Set 7 | nikolskoye
# Processing Record 17 of Set 7 | whitehorse
# Processing Record 18 of Set 7 | balkanabat
# Processing Record 19 of Set 7 | cayenne
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | portland
# Processing Record 22 of Set 7 | methana
# Processing Record 23 of Set 7 | waingapu
# Processing Record 24 of Set 7 | vaitape
# Processing Record 25 of Set 7 | tangkak
# Processing Record 26 of Set 7 | jacareacanga
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | comarapa
# Processing Record 29 of Set 7 | arlit
# Processing Record 30 of Set 7 | atar
# Processing Record 31 of Set 7 | khandbari
# Processing Record 32 of Set 7 | liberal
# Processing Record 33 of Set 7 | srednekolymsk
# Processing Record 34 of Set 7 | yerbogachen
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | mudanya
# Processing Record 38 of Set 7 | kununurra
# Processing Record 39 of Set 7 | iskateley
# Processing Record 40 of Set 7 | simbahan
# Processing Record 41 of Set 7 | ostersund
# Processing Record 42 of Set 7 | vanimo
# Processing Record 43 of Set 7 | makakilo city
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | santa marta
# Processing Record 46 of Set 7 | tynda
# Processing Record 47 of Set 7 | zhangye
# Processing Record 48 of Set 7 | victoria
# Processing Record 49 of Set 7 | saint-joseph
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | karomatan
# City not found. Skipping...
# Processing Record 2 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 8 | byron bay
# Processing Record 4 of Set 8 | bandarbeyla
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | fortuna
# Processing Record 7 of Set 8 | osypenko
# Processing Record 8 of Set 8 | aberlour
# City not found. Skipping...
# Processing Record 9 of Set 8 | general artigas
# Processing Record 10 of Set 8 | lumut
# Processing Record 11 of Set 8 | lexington
# Processing Record 12 of Set 8 | vikramasingapuram
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | nioro
# Processing Record 15 of Set 8 | bonthe
# Processing Record 16 of Set 8 | teguise
# Processing Record 17 of Set 8 | tupik
# Processing Record 18 of Set 8 | sa kaeo
# Processing Record 19 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 8 | da nang
# Processing Record 21 of Set 8 | solnechnyy
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | lezhe
# Processing Record 24 of Set 8 | payo
# Processing Record 25 of Set 8 | batagay-alyta
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | belmonte
# Processing Record 28 of Set 8 | hokitika
# Processing Record 29 of Set 8 | farmington
# Processing Record 30 of Set 8 | hwange
# Processing Record 31 of Set 8 | thetford mines
# Processing Record 32 of Set 8 | guerrero negro
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | marsa matruh
# Processing Record 35 of Set 8 | roma
# Processing Record 36 of Set 8 | richards bay
# Processing Record 37 of Set 8 | hanzhong
# Processing Record 38 of Set 8 | zeya
# Processing Record 39 of Set 8 | taga
# Processing Record 40 of Set 8 | biak
# Processing Record 41 of Set 8 | mizan teferi
# Processing Record 42 of Set 8 | pinaring
# Processing Record 43 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | kljajicevo
# Processing Record 45 of Set 8 | illintsi
# Processing Record 46 of Set 8 | syke
# Processing Record 47 of Set 8 | dickinson
# Processing Record 48 of Set 8 | kviteseid
# Processing Record 49 of Set 8 | karak
# Processing Record 50 of Set 8 | balkhash
# Processing Record 1 of Set 9 | harper
# Processing Record 2 of Set 9 | lambarene
# Processing Record 3 of Set 9 | corinto
# Processing Record 4 of Set 9 | gushikawa
# Processing Record 5 of Set 9 | te anau
# Processing Record 6 of Set 9 | nalut
# Processing Record 7 of Set 9 | canavieiras
# Processing Record 8 of Set 9 | upington
# Processing Record 9 of Set 9 | ancud
# Processing Record 10 of Set 9 | malvern
# Processing Record 11 of Set 9 | praia
# Processing Record 12 of Set 9 | kinanah
# City not found. Skipping...
# Processing Record 13 of Set 9 | murray bridge
# Processing Record 14 of Set 9 | tsuruoka
# Processing Record 15 of Set 9 | shestakovo
# Processing Record 16 of Set 9 | rumphi
# Processing Record 17 of Set 9 | derzhavinsk
# Processing Record 18 of Set 9 | ahipara
# Processing Record 19 of Set 9 | iralaya
# Processing Record 20 of Set 9 | tawang
# Processing Record 21 of Set 9 | cabedelo
# Processing Record 22 of Set 9 | denizli
# Processing Record 23 of Set 9 | mackay
# Processing Record 24 of Set 9 | uribia
# Processing Record 25 of Set 9 | daru
# Processing Record 26 of Set 9 | zhigansk
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | nabire
# Processing Record 29 of Set 9 | ipixuna
# Processing Record 30 of Set 9 | haines junction
# Processing Record 31 of Set 9 | alofi
# Processing Record 32 of Set 9 | fatezh
# Processing Record 33 of Set 9 | kavaratti
# Processing Record 34 of Set 9 | lensk
# Processing Record 35 of Set 9 | kuroiso
# Processing Record 36 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 9 | poum
# Processing Record 38 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 9 | gizo
# Processing Record 42 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 9 | barreirinha
# Processing Record 44 of Set 9 | coolum beach
# Processing Record 45 of Set 9 | gravdal
# Processing Record 46 of Set 9 | dongsheng
# Processing Record 47 of Set 9 | manzil salim
# Processing Record 48 of Set 9 | shu
# Processing Record 49 of Set 9 | kendrapara
# Processing Record 50 of Set 9 | tiznit
# Processing Record 1 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 10 | matara
# Processing Record 3 of Set 10 | beringovskiy
# Processing Record 4 of Set 10 | sabratah
# Processing Record 5 of Set 10 | nakatunguru
# Processing Record 6 of Set 10 | pitimbu
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | orlik
# Processing Record 9 of Set 10 | port lincoln
# Processing Record 10 of Set 10 | ituporanga
# Processing Record 11 of Set 10 | ugoofaaru
# Processing Record 12 of Set 10 | strezhevoy
# Processing Record 13 of Set 10 | anadyr
# Processing Record 14 of Set 10 | sunamganj
# City not found. Skipping...
# Processing Record 15 of Set 10 | descalvado
# Processing Record 16 of Set 10 | vila velha
# Processing Record 17 of Set 10 | guayanilla
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 20 of Set 10 | maraa
# Processing Record 21 of Set 10 | stirion
# Processing Record 22 of Set 10 | zapolyarnyy
# Processing Record 23 of Set 10 | ust-tsilma
# Processing Record 24 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 10 | qaqortoq
# Processing Record 26 of Set 10 | west bay
# Processing Record 27 of Set 10 | kahului
# Processing Record 28 of Set 10 | cortez
# Processing Record 29 of Set 10 | sarany
# Processing Record 30 of Set 10 | douglas
# Processing Record 31 of Set 10 | kutum
# Processing Record 32 of Set 10 | belyy yar
# Processing Record 33 of Set 10 | harigue
# City not found. Skipping...
# Processing Record 34 of Set 10 | humaita
# Processing Record 35 of Set 10 | kushiro
# Processing Record 36 of Set 10 | kirakira
# Processing Record 37 of Set 10 | dicabisagan
# Processing Record 38 of Set 10 | shubarshi
# Processing Record 39 of Set 10 | saint-pierre
# Processing Record 40 of Set 10 | santa maria
# Processing Record 41 of Set 10 | broken hill
# Processing Record 42 of Set 10 | pesochnyy
# Processing Record 43 of Set 10 | mount isa
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | cervo
# Processing Record 46 of Set 10 | port hardy
# Processing Record 47 of Set 10 | progreso
# Processing Record 48 of Set 10 | high level
# Processing Record 49 of Set 10 | port augusta
# Processing Record 50 of Set 10 | jurm
# Processing Record 1 of Set 11 | honiara
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | kizukuri
# Processing Record 4 of Set 11 | bambari
# Processing Record 5 of Set 11 | lander
# Processing Record 6 of Set 11 | kidal
# Processing Record 7 of Set 11 | matamoros
# Processing Record 8 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 9 of Set 11 | ereymentau
# Processing Record 10 of Set 11 | shimanovsk
# Processing Record 11 of Set 11 | mixtepec
# City not found. Skipping...
# Processing Record 12 of Set 11 | gamba
# Processing Record 13 of Set 11 | gunnedah
# Processing Record 14 of Set 11 | senmonorom
# City not found. Skipping...
# Processing Record 15 of Set 11 | taga dzong
# City not found. Skipping...
# Processing Record 16 of Set 11 | haapiti
# Processing Record 17 of Set 11 | lukulu
# Processing Record 18 of Set 11 | garbolovo
# Processing Record 19 of Set 11 | kalianget
# Processing Record 20 of Set 11 | saint-jean-port-joli
# Processing Record 21 of Set 11 | omboue
# Processing Record 22 of Set 11 | xambioa
# Processing Record 23 of Set 11 | dovolnoye
# Processing Record 24 of Set 11 | semirom
# Processing Record 25 of Set 11 | akyab
# Processing Record 26 of Set 11 | stornoway
# Processing Record 27 of Set 11 | vostok
# Processing Record 28 of Set 11 | betsiamites
# Processing Record 29 of Set 11 | lac du bonnet
# Processing Record 30 of Set 11 | la asuncion
# Processing Record 31 of Set 11 | madang
# Processing Record 32 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 11 | kasangulu
# Processing Record 34 of Set 11 | tuy hoa
# Processing Record 35 of Set 11 | conde
# Processing Record 36 of Set 11 | constitucion
# Processing Record 37 of Set 11 | bejar
# Processing Record 38 of Set 11 | canutama
# Processing Record 39 of Set 11 | shellbrook
# Processing Record 40 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 11 | novikovo
# Processing Record 42 of Set 11 | takoradi
# Processing Record 43 of Set 11 | severo-kurilsk
# Processing Record 44 of Set 11 | elmira
# Processing Record 45 of Set 11 | ostrovnoy
# Processing Record 46 of Set 11 | san felipe
# Processing Record 47 of Set 11 | liepaja
# Processing Record 48 of Set 11 | comitancillo
# Processing Record 49 of Set 11 | oriximina
# Processing Record 50 of Set 11 | arak
# Processing Record 1 of Set 12 | kemi
# Processing Record 2 of Set 12 | dauphin
# Processing Record 3 of Set 12 | solms
# Processing Record 4 of Set 12 | shirokiy
# Processing Record 5 of Set 12 | baie-comeau
# Processing Record 6 of Set 12 | santa maria del oro
# Processing Record 7 of Set 12 | puerto baquerizo moreno
# Processing Record 8 of Set 12 | parnamirim
# Processing Record 9 of Set 12 | hoi an
# Processing Record 10 of Set 12 | vao
# Processing Record 11 of Set 12 | caravelas
# Processing Record 12 of Set 12 | verkhnyaya khava
# Processing Record 13 of Set 12 | batagay
# Processing Record 14 of Set 12 | batemans bay
# Processing Record 15 of Set 12 | solenzo
# Processing Record 16 of Set 12 | houma
# Processing Record 17 of Set 12 | duz
# City not found. Skipping...
# Processing Record 18 of Set 12 | pueblo
# Processing Record 19 of Set 12 | san juan
# Processing Record 20 of Set 12 | lapugiu de jos
# Processing Record 21 of Set 12 | dawei
# Processing Record 22 of Set 12 | touros
# Processing Record 23 of Set 12 | hithadhoo
# Processing Record 24 of Set 12 | hostotipaquillo
# Processing Record 25 of Set 12 | todos santos
# Processing Record 26 of Set 12 | dhandhuka
# Processing Record 27 of Set 12 | kananga
# Processing Record 28 of Set 12 | ewa beach
# Processing Record 29 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 12 | fatikchhari
# City not found. Skipping...
# Processing Record 31 of Set 12 | semey
# Processing Record 32 of Set 12 | igarka
# Processing Record 33 of Set 12 | morant bay
# Processing Record 34 of Set 12 | saint-augustin
# Processing Record 35 of Set 12 | nantucket
# Processing Record 36 of Set 12 | teofilo otoni
# Processing Record 37 of Set 12 | russell
# Processing Record 38 of Set 12 | onega
# Processing Record 39 of Set 12 | udachnyy
# Processing Record 40 of Set 12 | bayburt
# Processing Record 41 of Set 12 | rawah
# Processing Record 42 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 12 | coquimbo
# Processing Record 44 of Set 12 | dire dawa
# Processing Record 45 of Set 12 | kenora
# Processing Record 46 of Set 12 | jiaonan
# Processing Record 47 of Set 12 | burnie
# Processing Record 48 of Set 12 | praya
# Processing Record 49 of Set 12 | moba
# Processing Record 50 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 13 | kyabe
# Processing Record 2 of Set 13 | ochamchira
# Processing Record 3 of Set 13 | eldorado
# Processing Record 4 of Set 13 | tbilisskaya
# Processing Record 5 of Set 13 | zalantun
# Processing Record 6 of Set 13 | abu zabad
# Processing Record 7 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 8 of Set 13 | maneadero
# Processing Record 9 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 13 | yavas
# Processing Record 11 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 12 of Set 13 | chapais
# Processing Record 13 of Set 13 | kruisfontein
# Processing Record 14 of Set 13 | ouadda
# Processing Record 15 of Set 13 | aripuana
# Processing Record 16 of Set 13 | rayevskiy
# Processing Record 17 of Set 13 | mbandaka
# Processing Record 18 of Set 13 | taitung
# Processing Record 19 of Set 13 | trairi
# Processing Record 20 of Set 13 | mwingi
# Processing Record 21 of Set 13 | jibuti
# Processing Record 22 of Set 13 | westport
# Processing Record 23 of Set 13 | micomeseng
# Processing Record 24 of Set 13 | kibala
# Processing Record 25 of Set 13 | inta
# Processing Record 26 of Set 13 | ornskoldsvik
# Processing Record 27 of Set 13 | tessalit
# Processing Record 28 of Set 13 | gafanha da encarnacao
# Processing Record 29 of Set 13 | katha
# City not found. Skipping...
# Processing Record 30 of Set 13 | mogok
# Processing Record 31 of Set 13 | dalian
# Processing Record 32 of Set 13 | beysehir
# Processing Record 33 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 13 | berlevag
# Processing Record 35 of Set 13 | chara
# Processing Record 36 of Set 13 | general pico
# Processing Record 37 of Set 13 | viedma
# Processing Record 38 of Set 13 | jiayuguan
# Processing Record 39 of Set 13 | odienne
# Processing Record 40 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 13 | brovary
# Processing Record 42 of Set 13 | praia da vitoria
# Processing Record 43 of Set 13 | guanica
# Processing Record 44 of Set 13 | maloy
# Processing Record 45 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 13 | tommot
# Processing Record 47 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 13 | sarkikaraagac
# Processing Record 49 of Set 13 | evensk
# Processing Record 50 of Set 13 | tete
# Processing Record 1 of Set 14 | mulege
# Processing Record 2 of Set 14 | laurel
# Processing Record 3 of Set 14 | flin flon
# Processing Record 4 of Set 14 | yaan
# Processing Record 5 of Set 14 | porto velho
# Processing Record 6 of Set 14 | road town
# Processing Record 7 of Set 14 | camopi
# Processing Record 8 of Set 14 | shar
# Processing Record 9 of Set 14 | maldonado
# Processing Record 10 of Set 14 | krapivinskiy
# Processing Record 11 of Set 14 | dunedin
# Processing Record 12 of Set 14 | hisar
# Processing Record 13 of Set 14 | sri aman
# Processing Record 14 of Set 14 | pietarsaari
# Processing Record 15 of Set 14 | hrubieszow
# Processing Record 16 of Set 14 | mana
# Processing Record 17 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 18 of Set 14 | bowen
# Processing Record 19 of Set 14 | farkhor
# Processing Record 20 of Set 14 | ulladulla
# Processing Record 21 of Set 14 | solano
# Processing Record 22 of Set 14 | cacahuatepec
# Processing Record 23 of Set 14 | kargat
# Processing Record 24 of Set 14 | niort
# Processing Record 25 of Set 14 | denpasar
# Processing Record 26 of Set 14 | boa vista
# Processing Record 27 of Set 14 | seymchan
# Processing Record 28 of Set 14 | kamaishi
# Processing Record 29 of Set 14 | gumia
# Processing Record 30 of Set 14 | dillon
# Processing Record 31 of Set 14 | lakheri
# Processing Record 32 of Set 14 | eregli
# Processing Record 33 of Set 14 | kapit
# Processing Record 34 of Set 14 | gemena
# Processing Record 35 of Set 14 | marigot
# Processing Record 36 of Set 14 | sept-iles
# Processing Record 37 of Set 14 | baghdad
# Processing Record 38 of Set 14 | jiaozhou
# Processing Record 39 of Set 14 | komsomolskiy
# Processing Record 40 of Set 14 | koslan
# Processing Record 41 of Set 14 | hendaye
# Processing Record 42 of Set 14 | vega de alatorre
# Processing Record 43 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 14 | general roca
# Processing Record 45 of Set 14 | pufesti
# Processing Record 46 of Set 14 | teya
# Processing Record 47 of Set 14 | mimongo
# Processing Record 48 of Set 14 | siderno
# Processing Record 49 of Set 14 | saldanha
# Processing Record 50 of Set 14 | najran
# Processing Record 1 of Set 15 | qeshm
# Processing Record 2 of Set 15 | tutoia
# Processing Record 3 of Set 15 | pacific grove
# Processing Record 4 of Set 15 | quatre cocos
# Processing Record 5 of Set 15 | talah
# City not found. Skipping...
# Processing Record 6 of Set 15 | khandyga
# Processing Record 7 of Set 15 | oksfjord
# Processing Record 8 of Set 15 | somerset west
# Processing Record 9 of Set 15 | mehamn
# Processing Record 10 of Set 15 | tadine
# Processing Record 11 of Set 15 | tigil
# Processing Record 12 of Set 15 | jurado
# Processing Record 13 of Set 15 | stromness
# Processing Record 14 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 15 | los andes
# Processing Record 16 of Set 15 | almaznyy
# Processing Record 17 of Set 15 | wanaka
# Processing Record 18 of Set 15 | menongue
# Processing Record 19 of Set 15 | portpatrick
# City not found. Skipping...
# Processing Record 20 of Set 15 | puerto carreno
# Processing Record 21 of Set 15 | fiche
# Processing Record 22 of Set 15 | mandalgovi
# Processing Record 23 of Set 15 | albury
# Processing Record 24 of Set 15 | ponta delgada
# Processing Record 25 of Set 15 | penzance
# Processing Record 26 of Set 15 | banamba
# Processing Record 27 of Set 15 | ocampo
# Processing Record 28 of Set 15 | shimoda
# Processing Record 29 of Set 15 | santa lucia
# Processing Record 30 of Set 15 | polonnaruwa
# Processing Record 31 of Set 15 | mareeba
# Processing Record 32 of Set 15 | valparaiso
# Processing Record 33 of Set 15 | sainte-maxime
# Processing Record 34 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 15 | nishihara
# Processing Record 36 of Set 15 | uvat
# Processing Record 37 of Set 15 | santa rita
# Processing Record 38 of Set 15 | avera
# Processing Record 39 of Set 15 | caibarien
# Processing Record 40 of Set 15 | pingdingshan
# Processing Record 41 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 15 | nkowakowa
# Processing Record 43 of Set 15 | cape canaveral
# Processing Record 44 of Set 15 | zhob
# Processing Record 45 of Set 15 | arman
# Processing Record 46 of Set 15 | san quintin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Determine length of list
print(len(city_data))
#Put data into a dataframe
city_data_df = pd.DataFrame(city_data)
# Out:
# 676

# %%
#Create a csv
output_data_file = "WeatherPy_Database.csv"
#Export dataframe to csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
